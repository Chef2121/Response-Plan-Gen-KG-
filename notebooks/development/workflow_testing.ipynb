# %% [markdown]
# # Traffic Management Workflow Testing
#
# This notebook is for testing and developing the traffic management system workflow.

# %%
# Setup and imports
import sys
import os

# Add the project root to the path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(project_root)

from src.agents.traffic_agent import RoadNetworkChatBot
from config.settings import settings

print("Project setup complete")
print(f"Neo4j URI: {settings.NEO4J_URI}")
print(f"Environment: {settings.ENVIRONMENT}")
# Out:
# Project setup complete
# Neo4j URI: bolt://localhost:7687
# Environment: development

# %%
# Initialize the traffic management chatbot
chatbot = RoadNetworkChatBot(verbose=True)
print("Chatbot initialized successfully")
# Out:
# Chatbot initialized successfully

# %%
# Test incident query
incident_query = """
Event id (38382929): At 08:45 this morning, a multi-vehicle accident occurred on road link 17840006094278 
near the junction with Elmwood Avenue. Two lanes are currently blocked, causing a queue of approximately 
750 meters. Emergency services are on site, and the incident has been active for 35 minutes. The severity 
is high due to the number of vehicles involved and the impact on traffic flow. Additional hazards include 
spilled fuel and debris on the road. Weather conditions are foggy, contributing to low visibility. 
Traffic volume is high due to rush hour.
"""

print("Testing traffic incident workflow...")
result = chatbot.query(incident_query)
print("Result:", result)

# %%
# Development notebook for testing the workflow
import sys
import os

# Add the project root to the path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))

from src.agents.traffic_agent import RoadNetworkChatBot

# Initialize the chatbot
chatbot = RoadNetworkChatBot(verbose=True)

# Test incident query
incident_query = """
Event id (38382929): At 08:45 this morning, a multi-vehicle accident occurred on road link 17840006094278 
near the junction with Elmwood Avenue. Two lanes are currently blocked, causing a queue of approximately 
750 meters. Emergency services are on site, and the incident has been active for 35 minutes. The severity 
is high due to the number of vehicles involved and the impact on traffic flow. Additional hazards include 
spilled fuel and debris on the road. Weather conditions are foggy, contributing to low visibility. 
Traffic volume is high due to rush hour.
"""

print("Testing traffic incident workflow...")
result = chatbot.query(incident_query)
print("Result:", result)
# Out:
# Testing traffic incident workflow...
# Starting query:
# Event id (38382929): At 08:45 this morning, a multi-vehicle accident occurred on road link 17840006094278
# near the junction with Elmwood Avenue. Two lanes are currently blocked, causing a queue of approximately
# 750 meters. Emergency services are on site, and the incident has been active for 35 minutes. The severity
# is high due to the number of vehicles involved and the impact on traffic flow. Additional hazards include
# spilled fuel and debris on the road. Weather conditions are foggy, contributing to low visibility.
# Traffic volume is high due to rush hour.
#
# Neo4j connection successful
# Result: []
